# %% [markdown]
# # Solution: Mid-Course Project 1

# %% [markdown]
# Hi there,
#
# We just finished collecting survey data from a few thousand customers who’ve purchased our alarm clocks (see attached spreadsheet).
# Can you clean up the data so I can pass it along to our research team to dive into next week?
#
# Thanks!\
# Alan
#
# *Attachment: Alarm Survey Data.xlsx*

# %% [markdown]
# ### 1. Read in data from an Excel spreadsheet and put into a Pandas DataFrame

# %%
import pandas as pd

# %%
df = pd.read_excel('../Data/Alarm Survey Data.xlsx')
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            NaN
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %% [markdown]
# ### 2. Quickly explore the DataFrame. Does anything immediately look odd?

# %%
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            NaN
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df.shape
# Out:
# (6433, 7)

# %%
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6330.000000
# mean   3216.302192    29.069175            1.395616       4.161453
# std    1856.007409     7.472048            1.432192       0.884997
# min       1.000000    13.000000            0.000000       2.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes  alarm_rating
# count        6433.000000   6433.000000
# mean            1.145811      2.955231
# std             1.599481      1.100875
# min             0.000000      1.000000
# 25%             0.000000      2.000000
# 50%             0.000000      3.000000
# 75%             2.000000      4.000000
# max            19.000000      5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6330 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 351.9+ KB

# %%
# Things noted:
# 5.5 children does not make sense
# 19 snoozes is a lot
# sleep quality has null values

# %% [markdown]
# ### 3. Is there any missing data? Resolve as needed.

# %%
# check for missing data
df[df.isna().any(axis=1)]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 4             5   30                 1.0  light_activity            NaN
# 6             7   41                 5.5  lightly active            NaN
# 7             8   36                 5.5  lightly active            NaN
# 17           18   41                 5.5     very active            NaN
# 91           92   31                 2.0  lightly active            NaN
# ...         ...  ...                 ...             ...            ...
# 5981       5982   35                 4.0          active            NaN
# 6010       6011   22                 3.0  light_activity            NaN
# 6194       6195   23                 1.0  lightly active            NaN
# 6317       6318   24                 1.0          active            NaN
# 6384       6318   24                 1.0          active            NaN
#
#       number_of_snoozes  alarm_rating
# 4                     4             3
# 6                     1             2
# 7                     1             2
# 17                    1             3
# 91                    1             2
# ...                 ...           ...
# 5981                  0             2
# 6010                  0             3
# 6194                  0             4
# 6317                  0             3
# 6384                  0             3
#
# [103 rows x 7 columns]

# %%
# sleep quality values
df.sleep_quality.value_counts(dropna=False)
# Out:
# 5.0    2721
# 4.0    2261
# 3.0     997
# 2.0     351
# NaN     103
# Name: sleep_quality, dtype: int64

# %%
# update sleep quality NaNs to 1
df.sleep_quality.fillna(1, inplace=True)

# %%
# sleep quality values
df.sleep_quality.value_counts(dropna=False)
# Out:
# 5.0    2721
# 4.0    2261
# 3.0     997
# 2.0     351
# 1.0     103
# Name: sleep_quality, dtype: int64

# %% [markdown]
# ### 4. Is there any inconsistent text or typos? Resolve as needed.

# %%
# check the numerical columns
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6433.000000
# mean   3216.302192    29.069175            1.395616       4.110835
# std    1856.007409     7.472048            1.432192       0.963415
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes  alarm_rating
# count        6433.000000   6433.000000
# mean            1.145811      2.955231
# std             1.599481      1.100875
# min             0.000000      1.000000
# 25%             0.000000      2.000000
# 50%             0.000000      3.000000
# 75%             2.000000      4.000000
# max            19.000000      5.000000

# %%
# look into number of children -- it just means 5+ kids, leave as is
df.number_of_children.value_counts()
# Out:
# 0.0    2440
# 2.0    1498
# 1.0    1172
# 3.0     788
# 4.0     331
# 5.5     204
# Name: number_of_children, dtype: int64

# %%
# check the categorical columms
df.activity_level.value_counts()
# Out:
# active            2450
# lightly active    2289
# light_activity     691
# very active        669
# light              334
# Name: activity_level, dtype: int64

# %%
# map the lightly active values to one value
import numpy as np

df.activity_level = np.where(df.activity_level.isin(['light_activity', 'light']), 'lightly active', df.activity_level)
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0  lightly active            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6428                  0             5
# 6429                  0             4
# 6430                  0             3
# 6431                  0             3
# 6432                  0             1
#
# [6433 rows x 7 columns]

# %%
# check the categorical columms
df.activity_level.value_counts()
# Out:
# lightly active    3314
# active            2450
# very active        669
# Name: activity_level, dtype: int64

# %% [markdown]
# ### 5. Is there any duplicate data? Resolve as needed.

# %%
# check for duplicate values
df[df.duplicated()]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 6366       6300   31                 2.0          active            5.0
# 6367       6301   27                 2.0  lightly active            4.0
# 6368       6302   41                 3.0  lightly active            5.0
# 6369       6303   25                 0.0  lightly active            5.0
# 6370       6304   25                 1.0  lightly active            5.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0  lightly active            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 6366                  0             3
# 6367                  0             2
# 6368                  0             2
# 6369                  0             5
# 6370                  0             2
# ...                 ...           ...
# 6428                  0             5
# 6429                  0             4
# 6430                  0             3
# 6431                  0             3
# 6432                  0             1
#
# [67 rows x 7 columns]

# %%
# save non-duplicates
df = df[~df.duplicated()]
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0  lightly active            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6361                  0             5
# 6362                  0             4
# 6363                  0             3
# 6364                  0             3
# 6365                  0             1
#
# [6366 rows x 7 columns]

# %% [markdown]
# ### 6. Are there any outliers? Resolve as needed.

# %%
# look into number of snoozes
df.number_of_snoozes.value_counts()
# Out:
# 0     3300
# 1     1229
# 2      693
# 4      427
# 5      345
# 3      309
# 6       59
# 8        2
# 19       1
# 7        1
# Name: number_of_snoozes, dtype: int64

# %%
import seaborn as sns

sns.boxplot(x=df.number_of_snoozes);

# %%
# let's only remove the extreme outlier
df = df.loc[df.number_of_snoozes < 18]
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                 2.0          active            5.0
# 6362       6363   31                 1.0  lightly active            4.0
# 6363       6364   26                 0.0  lightly active            5.0
# 6364       6365   27                 1.0          active            5.0
# 6365       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# 1                     3             3
# 2                     1             1
# 3                     1             4
# 4                     4             3
# ...                 ...           ...
# 6361                  0             5
# 6362                  0             4
# 6363                  0             3
# 6364                  0             3
# 6365                  0             1
#
# [6365 rows x 7 columns]

# %% [markdown]
# ### 7. Quickly explore the updated DataFrame. How do things look now?

# %%
# check for missing values
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
# check for inconsistent text
df.activity_level.value_counts()
# Out:
# lightly active    3287
# active            2422
# very active        656
# Name: activity_level, dtype: int64

# %%
# check for duplicate values
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
# check for outliers
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6365.000000  6365.000000         6365.000000    6365.000000
# mean   3183.882325    29.076826            1.396936       4.107620
# std    1837.741432     7.476376            1.433575       0.963612
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1593.000000    23.000000            0.000000       4.000000
# 50%    3184.000000    28.000000            1.000000       4.000000
# 75%    4775.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes  alarm_rating
# count        6365.000000   6365.000000
# mean            1.155067      2.955381
# std             1.587979      1.099921
# min             0.000000      1.000000
# 25%             0.000000      2.000000
# 50%             0.000000      3.000000
# 75%             2.000000      4.000000
# max             8.000000      5.000000

# %%
# first round of data cleaning is complete!
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0  lightly active            3.0
# 2          3   18                 0.0  lightly active            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  lightly active            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3
